# %%
# Import all necessary libraries
try:
    # %tensorflow_version 2.x
except Exception:
    pass
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras import optimizers
from tensorflow.keras import utils
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras import applications
from tensorflow.keras.regularizers import l2, l1

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 8.1 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 53.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 47.0 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 9.3 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.20.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import regex as re
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import math
import os

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K
import transformers
from transformers import RobertaTokenizer, TFRobertaModel

from collections import Counter

import warnings
warnings.filterwarnings("ignore")

# %%
# Import the training and test .csv files
import pandas as pd
colnames=['image_path', 'text', 'food']
train = pd.read_csv('/content/drive/MyDrive/Fusion/train_titles.csv', names=colnames, header=None, sep = ',', index_col=['image_path'])
test = pd.read_csv('/content/drive/MyDrive/Fusion/test_titles.csv', names=colnames, header=None, sep = ',', index_col=['image_path'])
print(test.shape[0])
# Out:
# 1375

# %%
# Sort values by 'image_path'
test = test.sort_values('image_path')
print(test.shape[0])
train = train.sort_values('image_path')
# Out:
# 1375

# %%
import numpy as np 
import glob
import os

def get_missing(file, df):
  parts = file.split(os.sep)
  #print(parts)
  idx = parts[-1]
  #print(idx)
  cls = parts[-2]  
  #print(cls)
  indexes = df[:,0]
  #print(indexes)
  classes = df[:,2]
  #print(classes)
  
 
  if idx in indexes:
    text = df[idx == indexes][0,1]
    return pd.NA, pd.NA, pd.NA
  
  else:
    text = df[cls == classes][:,1]
    return idx, text, cls   
  #print(idx)
vec_get_missing = np.vectorize(get_missing, signature='(),(m,n)->(),(),()')

# %%
# Function for images loading
from sklearn.utils import shuffle

def add_not_found(path, df):
  files = glob.glob(path)
  df = df.reset_index()
  idxs, texts, cls = vec_get_missing(files, df.values)
  #print(df.values)
  found = pd.DataFrame({"text": texts,
                        "food": cls,
                       "image_path": idxs})
  #print(idxs)
  na = found.isna().sum().values[0]
 # print(na)
  if na<found.shape[0]:
    df = df.append(found)
  df = df.drop_duplicates(subset='image_path', keep='first').dropna()
  df = df.set_index('image_path')
  df = shuffle(df, random_state = 0)
  return df

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Fusion/Dataset/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

testing_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Fusion/Dataset/test',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 4117 images belonging to 6 classes.
# Found 1375 images belonging to 6 classes.

# %%
tokenizer = RobertaTokenizer.from_pretrained('roberta-base')
# Out:
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
nClasses = train.food.nunique()

# %%
MAX_LEN= 50

# %%
# Preprocessing of texts according to BERT +
# Cleaning of the texts
import urllib.request
import re
import numpy as np
def preprocess_text(sen):
    # Removing html tags
    sentence = remove_tags(sen)
    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)
    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)
    # Removing multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)
    sentence = sentence.lower()
    return sentence

def remove_tags(text):
    return TAG_RE.sub('', text)

TAG_RE = re.compile(r'<[^>]+>')
vec_preprocess_text = np.vectorize(preprocess_text)

def get_tokens(text, tokenizer):
  tokens = tokenizer.tokenize(text)
  tokens = ["[CLS]"] + tokens + ["[SEP]"]
  length = len(tokens)
  if length > max_length:
      tokens = tokens[:max_length]
  return tokens, length  

def get_masks(text, tokenizer, max_length):
    """Mask for padding"""
    tokens, length = get_tokens(text, tokenizer)
    return np.asarray([1]*len(tokens) + [0] * (max_length - len(tokens)))
vec_get_masks = np.vectorize(get_masks, signature = '(),(),()->(n)')

def get_segments(text, tokenizer, max_length):
    """Segments: 0 for the first sequence, 1 for the second"""
    tokens, length = get_tokens(text, tokenizer)
    segments = []
    current_segment_id = 0
    for token in tokens:
        segments.append(current_segment_id)
        if token == "[SEP]":
            current_segment_id = 1
    return np.asarray(segments + [0] * (max_length - len(tokens)))
vec_get_segments = np.vectorize(get_segments, signature = '(),(),()->(n)')

def get_ids(text, tokenizer, max_length):
    """Token ids from Tokenizer vocab"""
    tokens, length = get_tokens(text, tokenizer)
    token_ids = tokenizer.convert_tokens_to_ids(tokens)
    input_ids = np.asarray(token_ids + [0] * (max_length-length))
    return input_ids
vec_get_ids = np.vectorize(get_ids, signature = '(),(),()->(n)')

def get_texts(path):
    path = path.decode('utf-8')
    parts = path.split(os.sep)
    image_name = parts[-1]
    is_train = parts[-3] == 'train'
    #print(train)
    if is_train:
      df = train
    else:
      df = test

    text = df['text'][image_name]
    return text

vec_get_text = np.vectorize(get_texts)
def prepare_text(paths):
    #Preparing texts
    
    texts = vec_get_text(paths)
    
    text_array = vec_preprocess_text(texts)
    ids = vec_get_ids(text_array, 
                      tokenizer, 
                      max_length).squeeze().astype(np.int32)
    masks = vec_get_masks(text_array,
                          tokenizer,
                          max_length).squeeze().astype(np.int32)
    segments = vec_get_segments(text_array,
                                tokenizer,
                                max_length).squeeze().astype(np.int32)
    
    return ids, segments, masks

def clean(i, tokens):
  try:
    this_token = tokens[i]
    next_token = tokens[i+1]
  except:
    return tokens
  if '##' in next_token:
      tokens.remove(next_token)
      tokens[i] = this_token + next_token[2:]
      tokens = clean(i, tokens)
      return tokens
  else:
    i = i+1
    tokens = clean(i, tokens)
    return tokens

def clean_text(array):
  array = array[(array!=0) & (array != 101) & (array != 102)]
  tokens = tokenizer.convert_ids_to_tokens(array)
  tokens = clean(0, tokens)
  text = ' '.join(tokens)
  return text

# %%
# Images preprocessing
import cv2
def load_image(path):
    path = path.decode('utf-8')
    image = cv2.imread(path)
    image = cv2.resize(image, (img_width, img_height))
    image = image/255
    #print(type(image))
    image = image.astype(np.float32)
    parts = path.split(os.sep)
    labels = parts[-2] == Classes 
    labels = labels.astype(np.int32)
    
    return image, labels
    
vec_load_image = np.vectorize(load_image, signature = '()->(r,c,d),(s)')

# %%
# Dataset creation

def prepare_data(paths):
    #Images and labels
    images, labels = tf.numpy_function(vec_load_image, 
                                      [paths], 
                                      [tf.float32, 
                                        tf.int32])   
    
    
    [ids, segments, masks, ] = tf.numpy_function(prepare_text, 
                                              [paths], 
                                              [tf.int32, 
                                               tf.int32,
                                               tf.int32])
    images.set_shape([None, img_width, img_height, depth])
    labels.set_shape([None, nClasses])
    ids.set_shape([None, max_length])
    masks.set_shape([None, max_length])
    segments.set_shape([None, max_length])
    return ({"input_word_ids": ids, 
             "input_mask": masks,  
             "segment_ids": segments, 
             "image": images},
            {"class": labels})
    

    return dataset

# %%
# Parameters setting: images width and height, depth, number if classes, input shape
#batch_size =  80
batch_size= 32
img_width = 299
img_height = 299
depth = 3
max_length = 50 #Setup according to the text
n=test.food.unique()
print(n)
nClasses = train.food.nunique()
print(nClasses)
Classes = train.food.unique()
print(Classes)
input_shape = (img_width, img_height, depth)
# Out:
# ['apple_pie' 'carrot_cake' 'cheesecake' 'club_sandwich' 'falafel'
#  'grilled_cheese_sandwich']
# 6
# ['apple_pie' 'carrot_cake' 'cheesecake' 'club_sandwich' 'falafel'
#  'grilled_cheese_sandwich']

# %%
# Images loading using tf.data
def tf_data(path, batch_size):
    paths = tf.data.Dataset.list_files(path)
    paths = paths.batch(64)
    dataset = paths.map(prepare_data, tf.data.experimental.AUTOTUNE)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    dataset = dataset.unbatch()
    dataset = dataset.batch(batch_size)
    dataset = dataset.repeat()
    return dataset   
data_train = tf_data('/content/drive/MyDrive/Fusion/Dataset/train/*/*.jpg', batch_size)
data_test = tf_data('/content/drive/MyDrive/Fusion/Dataset/test/*/*.jpg', batch_size)
#os.listdir('d:/Work Station/Image-and-Text-fusion-for-UPMC-Food-101-using-BERT-and-CNNs/Images/train')

# %%
import torch
import numpy as np
import datetime
# from inception_v4 import create_inception_v4
from torch.utils.data import DataLoader

# %%
from keras.layers import Input, concatenate , Dropout, Dense, Flatten, Activation
from keras.layers.convolutional import MaxPooling2D, Convolution2D, AveragePooling2D
from keras.layers import BatchNormalization
from keras.models import Model

from keras import backend as K
from keras.utils.data_utils import get_file

"""
Implementation of Inception Network v4 [Inception Network v4 Paper](http://arxiv.org/pdf/1602.07261v1.pdf) in Keras.
"""



def conv_block(x, nb_filter,nb_row, nb_col, padding='same', strides=(1, 1)):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    x = Convolution2D(nb_filter, (nb_row, nb_col), strides=strides, padding=padding)(x)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)
    return x


def inception_stem(input):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    # Input Shape is 299 x 299 x 3 (th) or 3 x 299 x 299 (th)
    x = conv_block(x=input, nb_filter=32, nb_row=3, nb_col=3, strides=(2,2), padding='valid')
    x = conv_block(x, 32, 3, 3, padding='valid')
    x = conv_block(x, 64, 3, 3)

    x1 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    x2 = conv_block(x, 96, 3, 3, strides=(2, 2), padding='valid')

    x = concatenate([x1, x2])

    x1 = conv_block(x, 64, 1, 1)
    x1 = conv_block(x1, 96, 3, 3, padding='valid')

    x2 = conv_block(x, 64, 1, 1)
    x2 = conv_block(x2, 64, 1, 7)
    x2 = conv_block(x2, 64, 7, 1)
    x2 = conv_block(x2, 96, 3, 3, padding='valid')

    x = concatenate([x1, x2])

    x1 = conv_block(x, 192, 3, 3, strides=(2, 2), padding='valid')
    x2 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)

    x = concatenate([x1, x2])
    return x


def inception_A(input):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    a1 = conv_block(input, 96, 1, 1)

    a2 = conv_block(input, 64, 1, 1)
    a2 = conv_block(a2, 96, 3, 3)

    a3 = conv_block(input, 64, 1, 1)
    a3 = conv_block(a3, 96, 3, 3)
    a3 = conv_block(a3, 96, 3, 3)

    a4 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    a4 = conv_block(a4, 96, 1, 1)

    m = concatenate([a1, a2, a3, a4])
    return m


def inception_B(input):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    b1 = conv_block(input, 384, 1, 1)

    b2 = conv_block(input, 192, 1, 1)
    b2 = conv_block(b2, 224, 1, 7)
    b2 = conv_block(b2, 256, 7, 1)

    b3 = conv_block(input, 192, 1, 1)
    b3 = conv_block(b3, 192, 7, 1)
    b3 = conv_block(b3, 224, 1, 7)
    b3 = conv_block(b3, 224, 7, 1)
    b3 = conv_block(b3, 256, 1, 7)

    b4 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    b4 = conv_block(b4, 128, 1, 1)

    m = concatenate([b1, b2, b3, b4])
    return m


def inception_C(input):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    c1 = conv_block(input, 256, 1, 1)

    c2 = conv_block(input, 384, 1, 1)
    c2_1 = conv_block(c2, 256, 1, 3)
    c2_2 = conv_block(c2, 256, 3, 1)
    c2 = concatenate([c2_1, c2_2])

    c3 = conv_block(input, 384, 1, 1)
    c3 = conv_block(c3, 448, 3, 1)
    c3 = conv_block(c3, 512, 1, 3)
    c3_1 = conv_block(c3, 256, 1, 3)
    c3_2 = conv_block(c3, 256, 3, 1)
    c3 = concatenate([c3_1, c3_2])

    c4 = AveragePooling2D((3, 3), strides=(1, 1), padding='same')(input)
    c4 = conv_block(c4, 256, 1, 1)

    m = concatenate([c1, c2, c3, c4])
    return m


def reduction_A(input):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = conv_block(input, 384, 3, 3, strides=(2, 2), padding='valid')

    r2 = conv_block(input, 192, 1, 1)
    r2 = conv_block(r2, 224, 3, 3)
    r2 = conv_block(r2, 256, 3, 3, strides=(2, 2), padding='valid')

    r3 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(input)

    m = concatenate([r1, r2, r3])
    return m


def reduction_B(input):
    if K.image_data_format() == "th":
        channel_axis = 1
    else:
        channel_axis = -1

    r1 = conv_block(input, 192, 1, 1)
    r1 = conv_block(r1, 192, 3, 3, strides=(2, 2), padding='valid')

    r2 = conv_block(input, 256, 1, 1)
    r2 = conv_block(r2, 256, 1, 7)
    r2 = conv_block(r2, 320, 7, 1)
    r2 = conv_block(r2, 320, 3, 3, strides=(2, 2), padding='valid')

    r3 = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(input)

    m = concatenate([r1, r2, r3])
    return m


def create_inception_v4(nb_classes=6):
    '''
    Creates a inception v4 network

    :param nb_classes: number of classes.txt
    :return: Keras Model with 1 input and 1 output
    '''

    if K.image_data_format() == 'th':
        init = Input((3, 299, 299))
    else:
        init = Input((299, 299, 3))

    # Input Shape is 299 x 299 x 3 (tf) or 3 x 299 x 299 (th)
    x = inception_stem(init)

    # 4 x Inception A
    for i in range(4):
        x = inception_A(x)

    # Reduction A
    x = reduction_A(x)

    # 7 x Inception B
    for i in range(7):
        x = inception_B(x)

    # Reduction B
    x = reduction_B(x)

    # 3 x Inception C
    for i in range(3):
        x = inception_C(x)

    # Average Pooling
    x = AveragePooling2D((8, 8))(x)

    # Dropout
    x = Dropout(0.8)(x)
    x = Flatten()(x)

    # Output
    x = Dense(256, activation='relu')(x)
    x = Dense(6, activation='softmax')(x)

    model = Model(init, x , name='Inception-v4')

    
    return model

# %%
model_inceptionv4 = create_inception_v4()

# %%
model_inceptionv4.summary()
# Out:
# Model: "Inception-v4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18496       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 96)   55392       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 96)  384         ['conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 73, 73, 96)   0           ['batch_normalization_3[0][0]']
#
#  concatenate (Concatenate)      (None, 73, 73, 160)  0           ['max_pooling2d[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 73, 73, 64)   10304       ['concatenate[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 73, 73, 64)   28736       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 73, 73, 64)   10304       ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 73, 73, 64)   28736       ['activation_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 73, 73, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_4[0][0]']
#
#  activation_8 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 71, 71, 96)   55392       ['activation_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 71, 71, 96)   55392       ['activation_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 71, 71, 96)  384         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 71, 71, 96)  384         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 71, 71, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_9 (Activation)      (None, 71, 71, 96)   0           ['batch_normalization_9[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 71, 71, 192)  0           ['activation_5[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 192)  331968      ['concatenate_1[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 192)  768        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['concatenate_1[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 35, 35, 384)  0           ['activation_10[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 96)  384         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_15 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 384)  0          ['concatenate_2[0][0]']
#  ing2D)
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_2[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 96)  384         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 96)  384         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  384         ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  384         ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_11[0][0]']
#
#  activation_13 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 35, 35, 384)  0           ['activation_11[0][0]',
#                                                                   'activation_13[0][0]',
#                                                                   'activation_16[0][0]',
#                                                                   'activation_17[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_3[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_3[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  256         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 96)  384         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_22[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 384)  0          ['concatenate_3[0][0]']
#  oling2D)
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_3[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 96)  384         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 96)  384         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  384         ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  384         ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 35, 35, 384)  0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]',
#                                                                   'activation_24[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 35, 35, 64)  256         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 35, 35, 96)  384         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_29[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 384)  0          ['concatenate_4[0][0]']
#  oling2D)
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_4[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 96)  384         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 96)  384         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 35, 35, 96)  384         ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 35, 35, 96)  384         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_25[0][0]']
#
#  activation_27 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_27[0][0]']
#
#  activation_30 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_30[0][0]']
#
#  activation_31 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_31[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 35, 35, 384)  0           ['activation_25[0][0]',
#                                                                   'activation_27[0][0]',
#                                                                   'activation_30[0][0]',
#                                                                   'activation_31[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_5[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 35, 35, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 35, 35, 64)   24640       ['concatenate_5[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_35[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 35, 35, 64)  256         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 35, 35, 96)  384         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_33[0][0]']
#
#  activation_36 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_36[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 35, 35, 384)  0          ['concatenate_5[0][0]']
#  oling2D)
#
#  conv2d_32 (Conv2D)             (None, 35, 35, 96)   36960       ['concatenate_5[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 35, 35, 96)   55392       ['activation_33[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 35, 35, 96)   83040       ['activation_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 35, 35, 96)   36960       ['average_pooling2d_3[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 35, 35, 96)  384         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 35, 35, 96)  384         ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 35, 35, 96)  384         ['conv2d_37[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 35, 35, 96)  384         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_32[0][0]']
#
#  activation_34 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_34[0][0]']
#
#  activation_37 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_37[0][0]']
#
#  activation_38 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_38[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 35, 35, 384)  0           ['activation_32[0][0]',
#                                                                   'activation_34[0][0]',
#                                                                   'activation_37[0][0]',
#                                                                   'activation_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 35, 35, 192)  73920       ['concatenate_6[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 35, 35, 192)  768        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 35, 35, 224)  387296      ['activation_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 35, 35, 224)  896        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 384)  1327488     ['concatenate_6[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 256)  516352      ['activation_41[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 384)  1536       ['conv2d_39[0][0]']
#  ormalization)
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_39[0][0]']
#
#  activation_42 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_42[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 384)  0          ['concatenate_6[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 17, 17, 1024  0           ['activation_39[0][0]',
#                                 )                                 'activation_42[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_7[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 192)  768        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  258240      ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  768        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_7[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 224)  301280      ['activation_48[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 192)  768        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 224)  896        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_44[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 224)  301280      ['activation_44[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 224)  351456      ['activation_49[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 224)  896        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 224)  896        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_45[0][0]']
#
#  activation_50 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_50[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 1024  0          ['concatenate_7[0][0]']
#  oling2D)                       )
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 384)  393600      ['concatenate_7[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 256)  401664      ['activation_45[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 256)  401664      ['activation_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 128)  131200      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 384)  1536       ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 256)  1024       ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 128)  512        ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_46[0][0]']
#
#  activation_51 (Activation)     (None, 17, 17, 256)  0           ['batch_normalization_51[0][0]']
#
#  activation_52 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_52[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 17, 17, 1024  0           ['activation_43[0][0]',
#                                 )                                 'activation_46[0][0]',
#                                                                   'activation_51[0][0]',
#                                                                   'activation_52[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_8[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 192)  768        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  258240      ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  768        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 192)  196800      ['concatenate_8[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 224)  301280      ['activation_58[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 192)  768        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 224)  896        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_54[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 224)  301280      ['activation_54[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 17, 17, 224)  351456      ['activation_59[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 224)  896        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 17, 17, 224)  896        ['conv2d_60[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_55[0][0]']
#
#  activation_60 (Activation)     (None, 17, 17, 224)  0           ['batch_normalization_60[0][0]']
#
# ...
#  batch_normalization_135 (Batch  (None, 8, 8, 512)   2048        ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_130 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_130[0][0]']
#
#  activation_135 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_135[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 8, 8, 256)    295168      ['activation_130[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 8, 8, 256)    295168      ['activation_130[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 8, 8, 256)    393472      ['activation_135[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 8, 8, 256)    393472      ['activation_135[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 8, 8, 1536)  0           ['concatenate_18[0][0]']
#  ooling2D)
#
#  conv2d_129 (Conv2D)            (None, 8, 8, 256)    393472      ['concatenate_18[0][0]']
#
#  batch_normalization_131 (Batch  (None, 8, 8, 256)   1024        ['conv2d_131[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 8, 8, 256)   1024        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_136 (Batch  (None, 8, 8, 256)   1024        ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 8, 8, 256)   1024        ['conv2d_137[0][0]']
#  Normalization)
#
#  conv2d_138 (Conv2D)            (None, 8, 8, 256)    393472      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_129 (Batch  (None, 8, 8, 256)   1024        ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_131[0][0]']
#
#  activation_132 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_132[0][0]']
#
#  activation_136 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_136[0][0]']
#
#  activation_137 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_137[0][0]']
#
#  batch_normalization_138 (Batch  (None, 8, 8, 256)   1024        ['conv2d_138[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_129[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 8, 8, 512)    0           ['activation_131[0][0]',
#                                                                   'activation_132[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 8, 8, 512)    0           ['activation_136[0][0]',
#                                                                   'activation_137[0][0]']
#
#  activation_138 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_138[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 8, 8, 1536)   0           ['activation_129[0][0]',
#                                                                   'concatenate_19[0][0]',
#                                                                   'concatenate_20[0][0]',
#                                                                   'activation_138[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 8, 8, 384)    590208      ['concatenate_21[0][0]']
#
#  batch_normalization_143 (Batch  (None, 8, 8, 384)   1536        ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 8, 8, 448)    516544      ['activation_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 8, 8, 448)   1792        ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_144[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 8, 8, 384)    590208      ['concatenate_21[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 8, 8, 512)    688640      ['activation_144[0][0]']
#
#  batch_normalization_140 (Batch  (None, 8, 8, 384)   1536        ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 8, 8, 512)   2048        ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_140[0][0]']
#
#  activation_145 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_145[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 8, 8, 256)    295168      ['activation_140[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 8, 8, 256)    295168      ['activation_140[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 8, 8, 256)    393472      ['activation_145[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 8, 8, 256)    393472      ['activation_145[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 8, 8, 1536)  0           ['concatenate_21[0][0]']
#  ooling2D)
#
#  conv2d_139 (Conv2D)            (None, 8, 8, 256)    393472      ['concatenate_21[0][0]']
#
#  batch_normalization_141 (Batch  (None, 8, 8, 256)   1024        ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 8, 8, 256)   1024        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_146 (Batch  (None, 8, 8, 256)   1024        ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 8, 8, 256)   1024        ['conv2d_147[0][0]']
#  Normalization)
#
#  conv2d_148 (Conv2D)            (None, 8, 8, 256)    393472      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_139 (Batch  (None, 8, 8, 256)   1024        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_141[0][0]']
#
#  activation_142 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_142[0][0]']
#
#  activation_146 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_146[0][0]']
#
#  activation_147 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_147[0][0]']
#
#  batch_normalization_148 (Batch  (None, 8, 8, 256)   1024        ['conv2d_148[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_139[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 8, 8, 512)    0           ['activation_141[0][0]',
#                                                                   'activation_142[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 8, 8, 512)    0           ['activation_146[0][0]',
#                                                                   'activation_147[0][0]']
#
#  activation_148 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_148[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 8, 8, 1536)   0           ['activation_139[0][0]',
#                                                                   'concatenate_22[0][0]',
#                                                                   'concatenate_23[0][0]',
#                                                                   'activation_148[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 1, 1, 1536)  0           ['concatenate_24[0][0]']
#  ooling2D)
#
#  dropout (Dropout)              (None, 1, 1, 1536)   0           ['average_pooling2d_14[0][0]']
#
#  flatten (Flatten)              (None, 1536)         0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 256)          393472      ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 6)            1542        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 41,632,582
# Trainable params: 41,569,414
# Non-trainable params: 63,168
# __________________________________________________________________________________________________

# %%
model_inceptionv4.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_inceptionv4, to_file='model_IV4.png')

# %%
input_word_ids = tf.keras.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_word_ids')
input_mask = tf.keras.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_mask')
segment_ids = tf.keras.Input(shape=(MAX_LEN,), dtype=tf.int32, name='segment_ids')
roberta_model = TFRobertaModel.from_pretrained('roberta-base')
x = roberta_model([input_word_ids,input_mask,segment_ids])
x = x[0]
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dense(256, activation='softmax')(x)
model_roberta = tf.keras.Model(inputs=[input_word_ids,input_mask,segment_ids], outputs=[x])
# Out:
# Downloading:   0%|          | 0.00/627M [00:00<?, ?B/s]
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.

# %%
for layer in model_roberta.layers:
    layer.trainable = True

# %%
model_roberta.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_word_ids (InputLayer)    [(None, 50)]         0           []
#
#  input_mask (InputLayer)        [(None, 50)]         0           []
#
#  segment_ids (InputLayer)       [(None, 50)]         0           []
#
#  tf_roberta_model (TFRobertaMod  TFBaseModelOutputWi  124645632  ['input_word_ids[0][0]',
#  el)                            thPoolingAndCrossAt               'input_mask[0][0]',
#                                 tentions(last_hidde               'segment_ids[0][0]']
#                                 n_state=(None, 50,
#                                 768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  dense_2 (Dense)                (None, 50, 256)      196864      ['tf_roberta_model[0][0]']
#
#  dense_3 (Dense)                (None, 50, 256)      65792       ['dense_2[0][0]']
#
#  flatten_1 (Flatten)            (None, 12800)        0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 256)          3277056     ['flatten_1[0][0]']
#
#  dense_5 (Dense)                (None, 256)          65792       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 128,251,136
# Trainable params: 128,251,136
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_roberta.compile(
            optimizer=tf.keras.optimizers.Adam(lr=1e-5),
            loss='categorical_crossentropy',
            metrics=['accuracy'])

# %%
plot_model(model_roberta, to_file='bert_roberta.png')

# %%
# Stacking early-fusion multimodal model

input_word_ids = layers.Input(shape=(max_length,), dtype=tf.int32,
                                       name="input_word_ids")
input_mask = layers.Input(shape=(max_length,), dtype=tf.int32,
                                   name="input_mask")
segment_ids = layers.Input(shape=(max_length,), dtype=tf.int32,
                                    name="segment_ids")
image_input = layers.Input(shape = input_shape, dtype=tf.float32,
                           name = "image")

image_side = model_inceptionv4(image_input)
text_side = model_roberta([input_word_ids, input_mask, segment_ids])
# Concatenate features from images and texts
merged = layers.Concatenate()([image_side, text_side])
merged = layers.Dense(224, activation = 'relu')(merged)
output = layers.Dense(nClasses, activation='softmax', name = "class")(merged)

# %%
model_combined= models.Model([input_word_ids, input_mask, segment_ids, image_input], output)

# %%
model_combined.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 299, 299, 3  0           []
#                                 )]
#
#  input_word_ids (InputLayer)    [(None, 50)]         0           []
#
#  input_mask (InputLayer)        [(None, 50)]         0           []
#
#  segment_ids (InputLayer)       [(None, 50)]         0           []
#
#  Inception-v4 (Functional)      (None, 6)            41632582    ['image[0][0]']
#
#  model (Functional)             (None, 256)          128251136   ['input_word_ids[0][0]',
#                                                                   'input_mask[0][0]',
#                                                                   'segment_ids[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 262)          0           ['Inception-v4[0][0]',
#                                                                   'model[0][0]']
#
#  dense_6 (Dense)                (None, 224)          58912       ['concatenate_25[0][0]']
#
#  class (Dense)                  (None, 6)            1350        ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 169,943,980
# Trainable params: 169,880,812
# Non-trainable params: 63,168
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model_combined, to_file='multimodal_RoBERTa+VGC16.png')

# %%
# Stochastic Gradient Descent optimizer
sgd = optimizers.SGD(learning_rate=0.0001, momentum=0.9, nesterov=False)

# Compile model
model_combined.compile(loss='categorical_crossentropy', 
              optimizer=sgd, 
              metrics=['accuracy'])

# %%
# Setup callbacks, logs and early stopping condition
import keras
from keras import callbacks
import numpy as np
import h5py
from keras.layers import Dense
from keras.callbacks import ModelCheckpoint
checkpoint_path = "stacking_early_fusion.weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
#checkpoint_path= "weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
cp = callbacks.ModelCheckpoint(checkpoint_path, monitor='val_accuracy',save_best_only=True, save_weights_only=True, verbose=1, mode='max')
print(cp)
csv_logger = callbacks.CSVLogger('StackingEarlyFusion.log')
print(csv_logger)
es = callbacks.EarlyStopping(patience = 3, restore_best_weights=True)
# Out:
# <keras.callbacks.ModelCheckpoint object at 0x7fe7df274110>
# <keras.callbacks.CSVLogger object at 0x7fe7df63edd0>

# %%
#Reduce learning rate if no improvement is observed
from keras.callbacks import ReduceLROnPlateau
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_accuracy', factor=0.1, patience=1, min_lr=0.00001)

# %%
# Training
history = model_combined.fit(data_train,
                    epochs=10,
                    steps_per_epoch = train.shape[0] //batch_size,
                    validation_data = data_test,
                    validation_steps = test.shape[0] //batch_size,
                    callbacks=[cp, csv_logger, reduce_lr])
# Out:
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model/roberta/pooler/dense/kernel:0', 'tf_roberta_model/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model/roberta/pooler/dense/kernel:0', 'tf_roberta_model/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 128/128 [==============================] - ETA: 0s - loss: 1.7934 - accuracy: 0.1597
# Epoch 1: val_accuracy improved from -inf to 0.16071, saving model to stacking_early_fusion.weights-improvement-01-0.16.hdf5
# 128/128 [==============================] - 1811s 13s/step - loss: 1.7934 - accuracy: 0.1597 - val_loss: 1.7926 - val_accuracy: 0.1607 - lr: 1.0000e-04
# Epoch 2/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7929 - accuracy: 0.1599
# Epoch 2: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 198s 2s/step - loss: 1.7929 - accuracy: 0.1599 - val_loss: 1.7924 - val_accuracy: 0.1600 - lr: 1.0000e-04
# Epoch 3/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7928 - accuracy: 0.1599
# Epoch 3: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7928 - accuracy: 0.1599 - val_loss: 1.7925 - val_accuracy: 0.1607 - lr: 1.0000e-05
# Epoch 4/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7934 - accuracy: 0.1594
# Epoch 4: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7934 - accuracy: 0.1594 - val_loss: 1.7925 - val_accuracy: 0.1600 - lr: 1.0000e-05
# Epoch 5/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7930 - accuracy: 0.1596
# Epoch 5: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7930 - accuracy: 0.1596 - val_loss: 1.7926 - val_accuracy: 0.1577 - lr: 1.0000e-05
# Epoch 6/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7926 - accuracy: 0.1618
# Epoch 6: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7926 - accuracy: 0.1618 - val_loss: 1.7924 - val_accuracy: 0.1607 - lr: 1.0000e-05
# Epoch 7/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7933 - accuracy: 0.1554
# Epoch 7: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7933 - accuracy: 0.1554 - val_loss: 1.7926 - val_accuracy: 0.1585 - lr: 1.0000e-05
# Epoch 8/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7930 - accuracy: 0.1647
# Epoch 8: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7930 - accuracy: 0.1647 - val_loss: 1.7925 - val_accuracy: 0.1600 - lr: 1.0000e-05
# Epoch 9/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7931 - accuracy: 0.1569
# Epoch 9: val_accuracy did not improve from 0.16071
# 128/128 [==============================] - 199s 2s/step - loss: 1.7931 - accuracy: 0.1569 - val_loss: 1.7924 - val_accuracy: 0.1592 - lr: 1.0000e-05
# Epoch 10/10
# 128/128 [==============================] - ETA: 0s - loss: 1.7925 - accuracy: 0.1608
# Epoch 10: val_accuracy improved from 0.16071 to 0.16146, saving model to stacking_early_fusion.weights-improvement-10-0.16.hdf5
# 128/128 [==============================] - 202s 2s/step - loss: 1.7925 - accuracy: 0.1608 - val_loss: 1.7922 - val_accuracy: 0.1615 - lr: 1.0000e-05
